# %%
import requests
import pandas as pd
import json
from pymongo import MongoClient

# %%
url = "https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativaMercadoMensais?$top=1000&$format=json&$select=Indicador,Data,DataReferencia,Media,Mediana,DesvioPadrao,Minimo,Maximo,numeroRespondentes,baseCalculo"
selic = "https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativasMercadoSelic?$top=1000&$format=json&$select=Indicador,Data,Reuniao,Media,Mediana,DesvioPadrao,Minimo,Maximo,numeroRespondentes,baseCalculo"
trimestral = "https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativasMercadoTrimestrais?$top=1000&$format=json&$select=Indicador,Data,DataReferencia,Media,Mediana,DesvioPadrao,Minimo,Maximo,numeroRespondentes,baseCalculo"
anual = "https://olinda.bcb.gov.br/olinda/servico/Expectativas/versao/v1/odata/ExpectativasMercadoAnuais?$top=1000&$format=json&$select=Indicador,IndicadorDetalhe,Data,DataReferencia,Media,Mediana,DesvioPadrao,Minimo,Maximo,numeroRespondentes,baseCalculo"
cliente = MongoClient("mongodb+srv://sauloadonesg_db_user:sHmCCaiuDfgoqPRN@cluster0.gfafwiq.mongodb.net/")
db = cliente["sauloadonesg_db"]

# %%
def requisicao_api(url1, url2, url3, url4):
    resposta = requests.get(url1)
    resposta2 = requests.get(url2)
    resposta3 = requests.get(url3)
    resposta4 = requests.get(url4)

    if(resposta.status_code == 200 and resposta2.status_code == 200 and resposta3.status_code == 200 and resposta4.status_code == 200):
        dados = resposta.json()
        dados2 = resposta2.json()
        dados3 = resposta3.json()
        dados4 = resposta4.json()
        with open('resultado.json', 'w', encoding='utf-8') as arquivo:
            json.dump(dados, arquivo, ensure_ascii=False, indent=4)
        with open('resultadoselic.json', 'w', encoding='utf-8') as arquivo:
            json.dump(dados2, arquivo, ensure_ascii=False, indent=4)
        with open('resultadotrimestral.json', 'w', encoding='utf-8') as arquivo:
            json.dump(dados3, arquivo, ensure_ascii=False, indent=4)
        with open('resultadoanual.json', 'w', encoding='utf-8') as arquivo:
            json.dump(dados4, arquivo, ensure_ascii=False, indent=4)

# %%
requisicao_api(url, selic, trimestral, anual)

# %%
jsondata = pd.read_json('resultado.json')

jsondata2 = pd.read_json('resultadoselic.json')
jsondata3 = pd.read_json("resultadotrimestral.json")
jsondata4 = pd.read_json("resultadoanual.json")

# %%
jsondata
jsondata2
jsondata3
jsondata4
# Out:
#                                         @odata.context  \
# 0    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# ..                                                 ...
# 995  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 996  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 997  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 998  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 999  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
#
#                                                  value
# 0    {'Indicador': 'Balança comercial', 'IndicadorD...
# 1    {'Indicador': 'Balança comercial', 'IndicadorD...
# 2    {'Indicador': 'Balança comercial', 'IndicadorD...
# 3    {'Indicador': 'Balança comercial', 'IndicadorD...
# ...

# %%
data = jsondata['value']
dataTri = jsondata3['value']
dataAnual = jsondata4['value']
dataSelic = jsondata2['value']

# %%
dados_df = pd.json_normalize(data)
dados_tri_df = pd.json_normalize(dataTri)
dados_anual_df = pd.json_normalize(dataAnual)
dados_selic_df = pd.json_normalize(dataSelic)

# %%
dados_df.head()
dados_tri_df.head()
dados_anual_df.head()
dados_selic_df.head()
# Out:
#   Indicador        Data  Reuniao    Media  Mediana  DesvioPadrao  Minimo  \
# 0     Selic  2025-09-19  R6/2027  10.6829    10.50        0.8818     9.0
# 1     Selic  2025-09-19  R6/2027  10.6829    10.50        0.8818     9.0
# 2     Selic  2025-09-19  R5/2027  10.7724    10.50        0.9411     9.0
# 3     Selic  2025-09-19  R5/2027  10.8532    10.75        0.9799     9.0
# 4     Selic  2025-09-19  R4/2027  11.0037    11.00        0.9024     9.0
#
#    Maximo  numeroRespondentes  baseCalculo
# 0    12.5                  41            1
# 1    12.5                  41            0
# 2    13.0                  67            1
# 3    13.0                 110            0
# 4    13.0                  69            1

# %%
jsondata = pd.read_json('resultado.json')
jsondata_tri = pd.read_json('resultadotrimestral.json')
jsondata_anual = pd.read_json('resultadoanual.json')
jsondata_selic = pd.read_json('resultadoselic.json')

# %%
jsondata
jsondata_tri
jsondata_selic
jsondata_anual
# Out:
#                                         @odata.context  \
# 0    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# ..                                                 ...
# 995  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 996  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 997  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 998  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 999  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
#
#                                                  value
# 0    {'Indicador': 'Balança comercial', 'IndicadorD...
# 1    {'Indicador': 'Balança comercial', 'IndicadorD...
# 2    {'Indicador': 'Balança comercial', 'IndicadorD...
# 3    {'Indicador': 'Balança comercial', 'IndicadorD...
# ...

# %%
dados_df.to_csv("dados.csv", index=False, encoding='utf-8')
dados_tri_df.to_csv("dadosTri.csv", index=False, encoding='utf-8')
dados_anual_df.to_csv("dadosAnual.csv", index=False, encoding='utf-8')
dados_selic_df.to_csv("dadosSelic.csv", index=False, encoding='utf-8')

# %%
print("Contagem de Valores nulos")
print(dados_df.isnull().sum())
print(dados_selic_df.isnull().sum())
print(dados_anual_df.isnull().sum())
print(dados_tri_df.isnull().sum())

print("Tipos de dados")
print(dados_df.dtypes)
print(dados_tri_df.dtypes)
print(dados_selic_df.dtypes)
print(dados_anual_df.dtypes)
# Out:
# Contagem de Valores nulos
# Indicador             0
# Data                  0
# DataReferencia        0
# Media                 0
# Mediana               0
# DesvioPadrao          0
# Minimo                0
# Maximo                0
# numeroRespondentes    0
# baseCalculo           0
# dtype: int64
# Indicador             0
# Data                  0
# Reuniao               0
# Media                 0
# Mediana               0
# DesvioPadrao          0
# Minimo                0
# Maximo                0
# numeroRespondentes    0
# baseCalculo           0
# dtype: int64
# Indicador                0
# IndicadorDetalhe         0
# Data                     0
# DataReferencia           0
# Media                    0
# Mediana                  0
# DesvioPadrao             0
# Minimo                   0
# Maximo                   0
# numeroRespondentes    1000
# baseCalculo              0
# dtype: int64
# Indicador             0
# Data                  0
# DataReferencia        0
# ...

# %%
dados_df = dados_df.rename(columns={"numeroRespondentes": "numResp", "DataReferencia": "dataRef", "DesvioPadrao": "desvPad"} )
dados_anual_df = dados_anual_df.rename(columns={"numeroRespondentes": "numResp", "DataReferencia": "dataRef", "DesvioPadrao": "desvPad"} )
dados_tri_df = dados_tri_df.rename(columns={"numeroRespondentes": "numResp", "DataReferencia": "dataRef", "DesvioPadrao": "desvPad"} )
dados_selic_df = dados_selic_df.rename(columns={"numeroRespondentes": "numResp", "DataReferencia": "dataRef", "DesvioPadrao": "desvPad"} )

# %%
dados_df
# Out:
#                Indicador        Data  dataRef   Media  Mediana  desvPad  \
# 0                   IPCA  2025-09-19  09/2027  0.2743    0.260   0.0996
#
#      numResp  baseCalculo
# 0        117            1
# ...

# %%
dados_selic_df
# Out:
#     Indicador        Data  Reuniao    Media  Mediana  desvPad  Minimo  Maximo  \
# 0       Selic  2025-09-19  R6/2027  10.6829   10.500   0.8818     9.0    12.5
# 1       Selic  2025-09-19  R6/2027  10.6829   10.500   0.8818     9.0    12.5
# 2       Selic  2025-09-19  R5/2027  10.7724   10.500   0.9411     9.0    13.0
# 3       Selic  2025-09-19  R5/2027  10.8532   10.750   0.9799     9.0    13.0
# 4       Selic  2025-09-19  R4/2027  11.0037   11.000   0.9024     9.0    13.0
# ..        ...         ...      ...      ...      ...      ...     ...     ...
# 995     Selic  2025-08-07  R4/2027  11.2870   11.375   1.0468     9.0    15.0
# 996     Selic  2025-08-07  R3/2027  11.3947   11.500   0.8934    10.0    13.5
# 997     Selic  2025-08-07  R3/2027  11.5376   11.500   1.0418     9.5    15.0
# 998     Selic  2025-08-07  R2/2027  11.6776   11.875   0.8939    10.0    14.0
# 999     Selic  2025-08-07  R2/2027  11.7982   12.000   1.0219     9.5    15.0
#
#      numResp  baseCalculo
# ...

# %%
dados_df['Data'] = pd.to_datetime(dados_df['Data'])
dados_tri_df['Data'] = pd.to_datetime(dados_tri_df['Data'])
dados_df['Data'] = dados_df['Data'].dt.strftime('%d-%m-%Y')
dados_tri_df['Data'] = dados_tri_df['Data'].dt.strftime('%d-%m-%Y')
dados_df
# Out:
#                Indicador        Data  dataRef   Media  Mediana  desvPad  \
# 0                   IPCA  19-09-2025  09/2027  0.2743    0.260   0.0996
# 1                   IPCA  19-09-2025  09/2027  0.2770    0.265   0.0968
# 2            IPCA Livres  19-09-2025  09/2027  0.2542    0.255   0.0923
# 3            IPCA Livres  19-09-2025  09/2027  0.2518    0.250   0.0873
# 4          IPCA Serviços  19-09-2025  09/2027  0.3716    0.380   0.1062
# ..                   ...         ...      ...     ...      ...      ...
# 995  Taxa de desocupação  17-09-2025  11/2026  6.3537    6.400   0.6261
# 996          IPCA Livres  17-09-2025  11/2026  0.3487    0.340   0.1027
# 997          IPCA Livres  17-09-2025  11/2026  0.3553    0.340   0.0983
# 998        IPCA Serviços  17-09-2025  11/2026  0.4009    0.370   0.1228
# 999        IPCA Serviços  17-09-2025  11/2026  0.3943    0.380   0.1173
#
#      Minimo  Maximo  numResp  baseCalculo
# 0    0.0659  0.6534       66            1
# ...

# %%
db["expectativas_mensal"].insert_many(dados_df.to_dict(orient="records"))
db["expectativas_anual"].insert_many(dados_anual_df.to_dict(orient="records"))
db["expectativas_trimestral"].insert_many(dados_tri_df.to_dict(orient="records"))
db["selic_diaria"].insert_many(dados_selic_df.to_dict(orient="records"))
print("Inserido.")
# Out:
# Inserido.
